# %%
# Import the random module.
import random

# %%
random.random()
# Out:
# 0.9086928182794657

# %%
random.randint(-90, 90)
# Out:
# 0

# %%
random_number = random.randint(-90, 89) + random.random()
random_number
# Out:
# 31.476102962709035

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1

# %%
random.randrange(-90, 90, step=1)
# Out:
# 89

# %%
random.uniform(-90, 90)
# Out:
# -33.493856322275825

# %%
# Import the NumPy module.
import numpy as np

# %%
np.random.uniform(-90.000, 90.000)
# Out:
# 37.85589372223613

# %%
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([ 53.45702572,  58.04646505, -73.62234641,   1.48993739,
#         13.80138752, -87.51546804,   7.89519871, -20.02346073,
#         -6.04805691,  62.57075299,  11.80135324,  84.25544522,
#        -82.58811278,  55.22164295, -82.94208324, -75.23240234,
#         54.34731152, -20.3721007 , -42.73917503, -57.24661109,
#         -1.25256094, -49.98741593, -39.81904848, -68.87248759,
#         73.75616224, -20.48796859,  65.23807709, -29.39733804,
#         39.89775022,  57.22405215, -74.59934962,  -0.95567688,
#         53.64903358, -86.73982904,  23.91427691,  89.83365082,
#        -38.49312165, -61.19811218, -56.36081085,   6.241694  ,
#         62.48138867,  57.75964345,  37.66578363, -55.99931984,
#        -67.05874009,  32.71330027,  -8.20209529, -80.3154665 ,
#        -80.2481289 ,  11.52692471])

# %%
# Import timeit.
import timeit

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 16.7 µs ± 482 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 1.57 ms ± 59.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
