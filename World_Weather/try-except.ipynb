# %%
import requests as req
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
cities = ["Pittsburgh", "Austin", "New York", "Los Angeles", "Seattle"]

# %%
for city in cities:
    try: 
        city_url = url + "&q=" + city
        weather = req.get(city_url).json()
        temp = weather['main']['temp']
    except KeyError:
          print('KeyError received for ' + city)  
          continue
    print("It is currently " + str(temp) + " degrees in " + city)
# Out:
# It is currently 73.89 degrees in Pittsburgh
# It is currently 80.64 degrees in Austin
# It is currently 66.29 degrees in New York
# It is currently 63.93 degrees in Los Angeles
# It is currently 55.83 degrees in Seattle
